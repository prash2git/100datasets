# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = "data/curves.csv"
df = pd.read_csv(data)


# Starting with the standard imports
# %matplotlib inline
import matplotlib.pyplot as plt                              # for plotting
import seaborn as sns                                        # nicer looking plots
sns.set()
plt.rcParams['figure.figsize'] = '20,10'
import warnings

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0           x1           x2           y
# count  1000.000000  1000.000000  1000.000000  1000.00000
# mean    499.500000     0.503665     0.246225     0.50000
# std     288.819436     0.919698     0.584413     0.50025
# min       0.000000    -1.597796    -1.262787     0.00000
# 25%     249.750000    -0.139181    -0.233408     0.00000
# 50%     499.500000     0.484482     0.255091     0.50000
# 75%     749.250000     1.167204     0.676270     1.00000
# max     999.000000     2.706983     1.805190     1.00000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'x1', 'x2', 'y'], dtype='object')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

plt.scatter(x=df.x1, y=df.x2, color=df.y.astype(str))

# %%
#Visualize the data and look for any linear models
sns.pairplot(df)


#warnings.filterwarnings('ignore')
#iris = sns.load_dataset("iris")
#list_of_cmaps=['Blues','Greens','Reds','Purples']
#g = sns.PairGrid(iris, hue="species", hue_kws={"cmap":list_of_cmaps})
#g = g.map_upper(plt.scatter)
#g = g.map_lower(sns.kdeplot,  shade=True, shade_lowest=False)
#g = g.map_diag(plt.hist)

# %%
print(df.shape)
# Out:
# (1000, 4)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'x1', 'x2', 'y'], dtype='object')

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Unnamed: 0        x1        x2  y
# 0             0  2.129573  0.629904  1
# 1             1  1.888882  0.146257  1
# 2             2 -0.190357  0.383993  0
# 3             3 -0.404416  0.195282  1
# 4             4  0.373012 -0.429716  1
# ..          ...       ...       ... ..
# 995         995  1.620491  0.309480  1
# 996         996  0.229913  1.004463  0
# 997         997  0.390582 -0.841455  1
# 998         998  0.244432  0.024923  1
# 999         999  0.428816 -0.591180  1
#
# [1000 rows x 4 columns]>

# %%
# Consider the scatterplot of the input features: (data1 is dataframe with gender replaced with numbers)
g = sns.PairGrid(df)
g = g.map_upper(plt.scatter)
g = g.map_lower(sns.kdeplot, shade=True, shade_lowest=False)
g = g.map_diag(plt.hist)
